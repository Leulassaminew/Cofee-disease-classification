# %%
import pandas as pd
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#     id      date    city       lat      long       pop    shop        brand  \
# 0  0.0  31/01/12  Athens  37.97945  23.71622  672130.0  shop_1  kinder-cola
# 1  1.0  31/01/12  Athens  37.97945  23.71622  672130.0  shop_1  kinder-cola
# 2  2.0  31/01/12  Athens  37.97945  23.71622  672130.0  shop_1  kinder-cola
# 3  3.0  31/01/12  Athens  37.97945  23.71622  672130.0  shop_1   adult-cola
# 4  4.0  31/01/12  Athens  37.97945  23.71622  672130.0  shop_1   adult-cola
#
#   container capacity  price  quantity
# 0     glass    500ml   0.96   13280.0
# 1   plastic    1.5lt   2.86    6727.0
# 2       can    330ml   0.87    9848.0
# 3     glass    500ml   1.00   20050.0
# 4       can    330ml   0.39   25696.0

# %%
df.container.value_counts()
# Out:
# plastic    4310
# glass      2154
# Name: container, dtype: int64

# %%
rep = {'can': 'plastic'}
df['container']=df['container'].replace(rep)

# %%
df.city.value_counts()
# Out:
# Athens          2160
# Irakleion       1080
# Patra           1080
# Thessaloniki    1080
# Larisa          1080
# Name: city, dtype: int64

# %%
r = {'Athens':'Addis Ababa','Irakelion':'Oromia','Patra':'Amhara','Thessaloniki':'Tigray','Larisa':'SPPR'}

# %%
df['city']=df['city'].replace(r)

# %%
df.head()
# Out:
#     id      date         city       lat      long       pop    shop  \
# 0  0.0  31/01/12  Addis Ababa  37.97945  23.71622  672130.0  shop_1
# 1  1.0  31/01/12  Addis Ababa  37.97945  23.71622  672130.0  shop_1
# 2  2.0  31/01/12  Addis Ababa  37.97945  23.71622  672130.0  shop_1
# 3  3.0  31/01/12  Addis Ababa  37.97945  23.71622  672130.0  shop_1
# 4  4.0  31/01/12  Addis Ababa  37.97945  23.71622  672130.0  shop_1
#
#           brand container capacity  price  quantity
# 0     Coca-Cola     glass    500ml   0.96   13280.0
# 1     Coca-Cola   plastic    1.5lt   2.86    6727.0
# 2     Coca-Cola   plastic    330ml   0.87    9848.0
# 3  Fanta-Orange     glass    500ml   1.00   20050.0
# 4  Fanta-Orange   plastic    330ml   0.39   25696.0

# %%
df.tail()
# Out:
#       id date city  lat  long  pop shop brand container capacity  price  \
# 7555 NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN       NaN      NaN    NaN
# 7556 NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN       NaN      NaN    NaN
# 7557 NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN       NaN      NaN    NaN
# 7558 NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN       NaN      NaN    NaN
# 7559 NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN       NaN      NaN    NaN
#
#       quantity
# 7555       NaN
# 7556       NaN
# 7557       NaN
# 7558       NaN
# 7559       NaN

# %%
df=df.dropna()

# %%
df.tail()
# Out:
#           id      date          city       lat      long       pop    shop  \
# 6475  6475.0  31/12/17        Athens  37.96245  23.68708  665871.0  shop_3
# 6476  6476.0  31/12/17        Larisa  39.63689  22.41761  144302.0  shop_5
# 6477  6477.0  31/12/17         Patra  38.24444  21.73444  168501.0  shop_6
# 6478  6478.0  31/12/17  Thessaloniki  40.64361  22.93086  353001.0  shop_4
# 6479  6479.0  31/12/17  Thessaloniki  40.64361  22.93086  353001.0  shop_4
#
#              brand container capacity  price  quantity
# 6475  orange-power   plastic    1.5lt   1.02   33201.0
# 6476  orange-power   plastic    330ml   0.47   46971.0
# 6477    adult-cola     glass    500ml   1.02   47708.0
# 6478        gazoza   plastic    1.5lt   1.34   27115.0
# 6479    adult-cola     glass    500ml   1.16   30413.0

# %%
df['brand'][0:100]
# Out:
# 0            Coca-Cola
# 1            Coca-Cola
# 2            Coca-Cola
# 3           adult-cola
# 4           adult-cola
#             ...
# 97     fanta pineapple
# 98     fanta pineapple
# 99              Sprite
# 100             Sprite
# 101             Sprite
# Name: brand, Length: 100, dtype: object

# %%
rp = {'kinder-cola':'Coca-Cola','adult-cola':'Fanta-Orange','lemon-boost':'Sprite','gazoza':'Fanta-pineapple','orange-power':'Schewpps'}

# %%
df['brand']=df['brand'].replace(rp)

# %%
df.brand.value_counts()
# Out:
# Coca-Cola          1279
# Fanta-Orange       1277
# Sprite             1277
# fanta pineapple    1275
# schewpps           1268
# Name: brand, dtype: int64

# %%
df.head()
# Out:
#     id      date    city       lat      long       pop    shop         brand  \
# 0  0.0  31/01/12  Athens  37.97945  23.71622  672130.0  shop_1     Coca-Cola
# 1  1.0  31/01/12  Athens  37.97945  23.71622  672130.0  shop_1     Coca-Cola
# 2  2.0  31/01/12  Athens  37.97945  23.71622  672130.0  shop_1     Coca-Cola
# 3  3.0  31/01/12  Athens  37.97945  23.71622  672130.0  shop_1  Fanta-Orange
# 4  4.0  31/01/12  Athens  37.97945  23.71622  672130.0  shop_1  Fanta-Orange
#
#   container capacity  price  quantity
# 0     glass    500ml   0.96   13280.0
# 1   plastic    1.5lt   2.86    6727.0
# 2   plastic    330ml   0.87    9848.0
# 3     glass    500ml   1.00   20050.0
# 4   plastic    330ml   0.39   25696.0

# %%
# Out:
# 0       19.2
# 1       57.2
# 2       17.4
# 3       20.0
# 4        7.8
#         ...
# 6475    20.4
# 6476     9.4
# 6477    20.4
# 6478    26.8
# 6479    23.2
# Name: price, Length: 6376, dtype: float64

# %%
df.head()
# Out:
#     id      date    city       lat      long       pop    shop         brand  \
# 0  0.0  31/01/12  Athens  37.97945  23.71622  672130.0  shop_1     Coca-Cola
# 1  1.0  31/01/12  Athens  37.97945  23.71622  672130.0  shop_1     Coca-Cola
# 2  2.0  31/01/12  Athens  37.97945  23.71622  672130.0  shop_1     Coca-Cola
# 3  3.0  31/01/12  Athens  37.97945  23.71622  672130.0  shop_1  Fanta-Orange
# 4  4.0  31/01/12  Athens  37.97945  23.71622  672130.0  shop_1  Fanta-Orange
#
#   container capacity  price  quantity
# 0     glass    500ml   0.96   13280.0
# 1   plastic    1.5lt   2.86    6727.0
# 2   plastic    330ml   0.87    9848.0
# 3     glass    500ml   1.00   20050.0
# 4   plastic    330ml   0.39   25696.0

# %%
df.head()
# Out:
#     id      date         city       lat      long       pop    shop  \
# 0  0.0  31/01/12  Addis Ababa  37.97945  23.71622  672130.0  shop_1
# 1  1.0  31/01/12  Addis Ababa  37.97945  23.71622  672130.0  shop_1
# 2  2.0  31/01/12  Addis Ababa  37.97945  23.71622  672130.0  shop_1
# 3  3.0  31/01/12  Addis Ababa  37.97945  23.71622  672130.0  shop_1
# 4  4.0  31/01/12  Addis Ababa  37.97945  23.71622  672130.0  shop_1
#
#           brand container capacity  price  quantity
# 0     Coca-Cola     glass    500ml   0.96   13280.0
# 1     Coca-Cola   plastic    1.5lt   2.86    6727.0
# 2     Coca-Cola   plastic    330ml   0.87    9848.0
# 3  Fanta-Orange     glass    500ml   1.00   20050.0
# 4  Fanta-Orange   plastic    330ml   0.39   25696.0

# %%
import pandas as pd
df = pd.read_csv("train.csv")
rep = {'can': 'plastic'}
df['container']=df['container'].replace(rep)
r = {'Athens':'Addis Ababa','Irakelion':'Oromia','Patra':'Amhara','Thessaloniki':'Tigray','Larisa':'SPPR'}
df['city']=df['city'].replace(r)
df=df.dropna()
rp = {'kinder-cola':'Coca-Cola','adult-cola':'Fanta-Orange','lemon-boost':'Sprite','gazoza':'Fanta-pineapple','orange-power':'Schewpps'}
df['brand']=df['brand'].replace(rp)
df.drop('date',axis=1)
# Out:
#           id         city       lat      long       pop    shop  \
# 0        0.0  Addis Ababa  37.97945  23.71622  672130.0  shop_1
# 1        1.0  Addis Ababa  37.97945  23.71622  672130.0  shop_1
# 2        2.0  Addis Ababa  37.97945  23.71622  672130.0  shop_1
# 3        3.0  Addis Ababa  37.97945  23.71622  672130.0  shop_1
# 4        4.0  Addis Ababa  37.97945  23.71622  672130.0  shop_1
# ...      ...          ...       ...       ...       ...     ...
# 6475  6475.0  Addis Ababa  37.96245  23.68708  665871.0  shop_3
# 6476  6476.0         SPPR  39.63689  22.41761  144302.0  shop_5
# 6477  6477.0       Amhara  38.24444  21.73444  168501.0  shop_6
# 6478  6478.0       Tigray  40.64361  22.93086  353001.0  shop_4
# 6479  6479.0       Tigray  40.64361  22.93086  353001.0  shop_4
#
#                 brand container capacity  price  quantity
# 0           Coca-Cola     glass    500ml   0.96   13280.0
# 1           Coca-Cola   plastic    1.5lt   2.86    6727.0
# ...

# %%
df.capacity.value_counts()
# Out:
# 1.5lt    357
# 330ml    352
# 500ml    349
# Name: capacity, dtype: int64

# %%
df.to_csv('tra.csv',index=False)

# %%
import pandas as pd
df = pd.read_csv("test.csv")
df.drop('date',axis=1)
rep = {'can': 'plastic'}
df['container']=df['container'].replace(rep)
r1 = {'Athens':'Addis Ababa','Irakleion':'Oromia','Patra':'Amhara','Thessaloniki':'Tigray','Larisa':'SPPR'}
df['city']=df['city'].replace(r1)
df=df.dropna()
rp = {'kinder-cola':'Coca-Cola','adult-cola':'Fanta-Orange','lemon-boost':'Sprite','gazoza':'Fanta-pineapple','orange-power':'Schewpps'}
df['brand']=df['brand'].replace(rp)
r={'1.5lt':1,'330ml':352,'500ml':500}
df['capacity']=df['capacity'].replace(r)

# %%
df.city.value_counts()
# Out:
# Addis Ababa    2122
# Tigray         1066
# Amhara         1065
# SPPR           1062
# Oromia         1061
# Name: city, dtype: int64

# %%
df.head()
# Out:
#      id      date         city       lat      long     pop    shop  \
# 0  6480  31/01/18  Addis Ababa  37.97945  23.71622  664046  shop_1
# 1  6481  31/01/18  Addis Ababa  37.97945  23.71622  664046  shop_1
# 2  6482  31/01/18  Addis Ababa  37.97945  23.71622  664046  shop_1
# 3  6483  31/01/18  Addis Ababa  37.97945  23.71622  664046  shop_1
# 4  6484  31/01/18  Addis Ababa  37.97945  23.71622  664046  shop_1
#
#           brand container  capacity  price  quantity
# 0     Coca-Cola   plastic         1   3.10      7056
# 1     Coca-Cola   plastic       352   0.85     12490
# 2  Fanta-Orange     glass       500   0.83     26640
# 3      Schewpps     glass       500   0.54     41892
# 4      Schewpps   plastic         1   0.83     22923

# %%
df.to_csv('tesf.csv',index=False)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
df = pd.read_csv("tra.csv")
d = pd.read_csv("tes.csv")
r={'1.5lt':1,'330ml':352,'500ml':500}
df['capacity']=df['capacity'].replace(r)
d['capacity']=d['capacity'].replace(r)
df=df.drop('date',axis=1)
d=d.drop('date',axis=1)
print(df.head())
df = pd.concat([df.drop('city',axis=1),pd.get_dummies(df.city)],axis=1)
df = pd.concat([df.drop('shop',axis=1),pd.get_dummies(df.shop)],axis=1)
df = pd.concat([df.drop('brand',axis=1),pd.get_dummies(df.brand)],axis=1)
df = pd.concat([df.drop('container',axis=1),pd.get_dummies(df.container)],axis=1)
d = pd.concat([d.drop('city',axis=1),pd.get_dummies(d.city)],axis=1)
d = pd.concat([d.drop('shop',axis=1),pd.get_dummies(d.shop)],axis=1)
d = pd.concat([d.drop('brand',axis=1),pd.get_dummies(d.brand)],axis=1)
d = pd.concat([d.drop('container',axis=1),pd.get_dummies(d.container)],axis=1)
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(18,12))
sns.heatmap(df.corr(), annot=False, cmap='coolwarm')
correlations = df.corr()['quantity'].abs()
sorted_correlations = correlations.sort_values()
num_cols_to_drop = int(0.8*len(df.columns))
cols_to_drop = sorted_correlations.iloc[:num_cols_to_drop].index
df_dropped = df.drop(cols_to_drop,axis=1)
train_x = df.drop('quantity',axis=1)
train_y = df['quantity']
test_x = d.drop('quantity',axis=1)
test_y = d['quantity']
forest = RandomForestClassifier()
forest.fit(train_x,train_y)
print(forest.score(test_x,test_y))
# Out:
#     id         city       lat      long       pop    shop         brand  \
# 0  0.0  Addis Ababa  37.97945  23.71622  672130.0  shop_1     Coca-Cola
# 1  1.0  Addis Ababa  37.97945  23.71622  672130.0  shop_1     Coca-Cola
# 2  2.0  Addis Ababa  37.97945  23.71622  672130.0  shop_1     Coca-Cola
# 3  3.0  Addis Ababa  37.97945  23.71622  672130.0  shop_1  Fanta-Orange
# 4  4.0  Addis Ababa  37.97945  23.71622  672130.0  shop_1  Fanta-Orange
#
#   container  capacity  price  quantity
# 0     glass       500   0.96   13280.0
# 1   plastic         1   2.86    6727.0
# 2   plastic       352   0.87    9848.0
# 3     glass       500   1.00   20050.0
# 4   plastic       352   0.39   25696.0
