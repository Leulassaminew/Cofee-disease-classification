# %%
import cv2
import os

# %%
input_dir = "C:\\Users\\azeb\\Desktop\\coffee disease\\002_strategy_just_single_leaves\\train\\Healthy"
output_dir = "C:\\Users\\azeb\\Desktop\\coffee disease\\002_strategy_just_single_leaves\\new resized"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
